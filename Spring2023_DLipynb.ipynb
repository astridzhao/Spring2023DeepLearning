# %% [markdown]
# <a href="https://colab.research.google.com/github/AstridZhao/Spring2023DeepLearning/blob/main/Spring2023_DLipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display
import numpy as np
import cv2
# %matplotlib inline
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# !wget "https://hips.hearstapps.com/hmg-prod/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg"
#img = cv2.imread('/Users/astridz/Documents/poppy.jpeg')
#lm=display.Image("https://hips.hearstapps.com/hmg-prod/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg", width = 500)
#lm
# Out:
# --2023-02-13 15:15:17--  https://hips.hearstapps.com/hmg-prod/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg
# Resolving hips.hearstapps.com (hips.hearstapps.com)... 151.101.0.155, 151.101.64.155, 151.101.128.155, ...
# Connecting to hips.hearstapps.com (hips.hearstapps.com)|151.101.0.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229955 (225K) [image/jpeg]
# Saving to: ‘dog-puppy-on-garden-royalty-free-image-1586966191.jpg.5’
#
# dog-puppy-on-garden 100%[===================>] 224.57K  --.-KB/s    in 0.02s
#
# 2023-02-13 15:15:17 (12.0 MB/s) - ‘dog-puppy-on-garden-royalty-free-image-1586966191.jpg.5’ saved [229955/229955]

# %%
img_color = cv2.imread('dog-puppy-on-garden-royalty-free-image-1586966191.jpg')

cv2.rectangle(img_color, pt1=(1969,0), pt2=(1999,30), color=(0,0,0), thickness=-1)

plt.imshow(img_color)
plt.axis("on")
plt.show()
